# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_SVM_linear.sav",'rb'))
result=loaded_model.predict([[2344,345,435,0,1]])

# %%
result
# Out:
# array([53467866.43004344])
