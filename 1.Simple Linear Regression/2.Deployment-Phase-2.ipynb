# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_linear.sav",'rb')) # 
result=loaded_model.predict([[15]]) # passing the input and store the value in the result variable
# Out:
# C:\Users\Suganya.Srihari\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[167181.3106341]])
